# %% [markdown]
# Conectado a Projeto_ap2 (3.13.13) (Python 3.13.13)

# %%
import pandas as pd

# %%
df = pd.read_excel("planilhao.xlsx", sheet_name="soja3")

# %%
filtro = df["Conta"]=="EBIT"
df.columns
# Out:
# Index(['Conta', 'Variação Trimestral', 'Variação Anual', '20254T', '20252T',
#        '20251T', '20244T', '20243T', '20242T', '20241T', '20234T', '20233T',
#        '20232T', '20231T', '20224T', '20223T', '20222T', '20221T', '20214T',
#        '20213T', '20212T', '20211T', '20204T', '20203T'],
#       dtype='str')

# %%
import pandas as pd
df = pd.read_excel("planilhao.xlsx", sheet_name="soja3")
# Selecioando as colunas que tenha valor "EBIT"
filtro = df["Conta"]=="EBIT"
df.columns
colunas = ['20254T', '20252T',
       '20251T', '20244T', '20243T', '20242T', '20241T', '20234T', '20233T',
       '20232T', '20231T', '20224T', '20223T', '20222T', '20221T', '20214T',
       '20213T', '20212T', '20211T', '20204T', '20203T']
colunas = sorted(colunas)
# instalar a biblioteca matplotlib (uv add matplotlib)
ebit = df[filtro][colunas].iloc[0]
sn.lineplot(x=colunas, y=ebit.values)
# Out:
# <Axes: >

# %%
import seaborn as sn

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("planilhao.xlsx", sheet_name="soja3")

# %%
filtro_lucro_liquido = df["Conta"]=="Lucro Líquido"

# %%
filtro_lucro_liquido = df["Conta"]=="Lucro Líquido"
df.columns
# Out:
# Index(['Conta', 'Variação Trimestral', 'Variação Anual', '20254T', '20252T',
#        '20251T', '20244T', '20243T', '20242T', '20241T', '20234T', '20233T',
#        '20232T', '20231T', '20224T', '20223T', '20222T', '20221T', '20214T',
#        '20213T', '20212T', '20211T', '20204T', '20203T'],
#       dtype='str')

# %%
colunas = sorted(colunas)

# %%
lucro_liquido = df[filtro_lucro_liquido][colunas].iloc[0]

# %%
lucro_liquido = df[filtro_lucro_liquido][colunas].iloc[0]
sn.lineplot(x=colunas, y=lucro_liquido.values)

sn.lineplot(lucro_liquido)
sn.histplot(lucro_liquido)
sn.boxplot(lucro_liquido)
# Out:
# <Axes: xlabel='4', ylabel='4'>

# %%
sn.histplot(lucro_liquido)
# Out:
# <Axes: xlabel='4', ylabel='Count'>

# %%
sn.boxplot(lucro_liquido)
# Out:
# <Axes: ylabel='4'>

# %%
import pandas as pd

# %%
import seaborn as sn

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("planilhao.xlsx", sheet_name="Sheet1")

# %%
plt.figure(figsize=(10,6)) #tamanho do grafico
sn.countplot(data=df, x="setor", order=df['setor'].value_counts().index)
# Out:
# <Axes: xlabel='setor', ylabel='count'>

# %%
plt.figure(figsize=(10,6)) #tamanho do grafico
sn.countplot(data=df, x="setor", order=df['setor'].value_counts().index)
plt.title("Grafico de Barras por setor")
plt.xlabel("Numero de empresas")
plt.ylabel("Setor")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6)) #tamanho do grafico
sn.countplot(data=df, y="setor", order=df['setor'].value_counts().index)
plt.title("Grafico de Barras por setor")
plt.xlabel("Numero de empresas")
plt.ylabel("Setor")
plt.xticks(rotation=45)
plt.show()

# %%
setor = df["setor"].value_counts()
plt.figure(figsize=(10,6)) #tamanho do grafico
plt.pie(setor, labels=setor.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x269ce914d70>,
#   <matplotlib.patches.Wedge at 0x269d58a0050>,
#   <matplotlib.patches.Wedge at 0x269d58a02d0>,
#   <matplotlib.patches.Wedge at 0x269d58a0550>,
#   <matplotlib.patches.Wedge at 0x269d58a07d0>,
#   <matplotlib.patches.Wedge at 0x269d58a0a50>,
#   <matplotlib.patches.Wedge at 0x269d58a0cd0>,
#   <matplotlib.patches.Wedge at 0x269d58a0f50>,
#   <matplotlib.patches.Wedge at 0x269d58a11d0>,
#   <matplotlib.patches.Wedge at 0x269d58a1450>,
#   <matplotlib.patches.Wedge at 0x269d58a16d0>,
#   <matplotlib.patches.Wedge at 0x269d58a1950>,
#   <matplotlib.patches.Wedge at 0x269d58a1bd0>,
#   <matplotlib.patches.Wedge at 0x269d58a1e50>,
#   <matplotlib.patches.Wedge at 0x269d58a20d0>,
#   <matplotlib.patches.Wedge at 0x269d58a2350>,
#   <matplotlib.patches.Wedge at 0x269d58a25d0>,
#   <matplotlib.patches.Wedge at 0x269d58a2990>,
#   <matplotlib.patches.Wedge at 0x269d58a2c10>,
#   <matplotlib.patches.Wedge at 0x269d58a2e90>,
#   <matplotlib.patches.Wedge at 0x269d58a3110>,
#   <matplotlib.patches.Wedge at 0x269d58a3250>,
#   <matplotlib.patches.Wedge at 0x269d58a34d0>],
#  [Text(1.0445446512877443, 0.34485717545987743, 'indústria'),
#   Text(0.6444598999377193, 0.8914434571930319, 'energia'),
#   Text(0.02598059519701404, 1.0996931429599845, 'construção'),
#   Text(-0.5574837055997753, 0.9482678513957664, 'consumo'),
#   Text(-0.9348363192131757, 0.5797249833153317, 'saúde'),
#   Text(-1.0937916849483256, 0.11670368433731351, 'banco'),
#   Text(-1.048544646876937, -0.3324968022488629, 'transporte'),
#   Text(-0.8600145462290001, -0.685838887986477, 'tecnologia'),
#   Text(-0.5797248310111556, -0.9348364136623515, 'varejo'),
#   Text(-0.3076387379691327, -1.056105301047561, 'químico'),
#   Text(-0.09083733137117753, -1.0962429380522198, 'madeira-papel'),
#   Text(0.11670405378321114, -1.0937916455296985, 'educação'),
#   Text(0.3200904432811243, -1.0523982649739088, 'siderurgico'),
#   Text(0.5005470304994795, -0.9795165492517997, 'financeiro'),
#   Text(0.644460002668475, -0.8914433829248772, 'saneamento'),
#   Text(0.7639166248727355, -0.79147418798281, 'telecom'),
#   Text(0.8680543608214815, -0.6756342402948577, 'agrícola'),
#   Text(0.9482679067804636, -0.55748361139158, 'petróleo'),
#   Text(1.0073503960429266, -0.4418655673303355, 'mineração'),
#   Text(1.048544654806906, -0.3324967772413237, 'proteína'),
#   Text(1.0752365969559263, -0.23209106093651874, 'seguro'),
#   Text(1.0923370478487222, -0.12961394175449825, 'shopping'),
#   Text(1.0993095812060039, -0.03896722557073671, 'supermercado')])

# %%
filtro = df["setor"]== 'agrícola'
df_setor = df[filtro]
sn.histplot(df["roe"], bins=20, kde=True, color='blue')
# Out:
# <Axes: xlabel='roe', ylabel='Count'>
